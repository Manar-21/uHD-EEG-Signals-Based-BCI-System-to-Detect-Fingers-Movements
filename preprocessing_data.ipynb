# %%
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #**Collect data from S5 file**

# %%
mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run1.mat')
S5_run1 = mat.get('y')
S5_run1 = pd.DataFrame(S5_run1)
S5_run1_transposed = S5_run1.transpose()   

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run2.mat')
S5_run2 = mat.get('y')
S5_run2 = pd.DataFrame(S5_run2)
S5_run2_transposed = S5_run2.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run3.mat')
S5_run3 = mat.get('y')
S5_run3 = pd.DataFrame(S5_run3)
S5_run3_transposed = S5_run3.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run4.mat')
S5_run4 = mat.get('y')
S5_run4 = pd.DataFrame(S5_run4)
S5_run4_transposed = S5_run4.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run5.mat')
S5_run5 = mat.get('y')
S5_run5 = pd.DataFrame(S5_run5)
S5_run5_transposed = S5_run5.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run6.mat')
S5_run6 = mat.get('y')
S5_run6 = pd.DataFrame(S5_run6)
S5_run6_transposed = S5_run6.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run7.mat')
S5_run7 = mat.get('y')
S5_run7 = pd.DataFrame(S5_run7)
S5_run7_transposed = S5_run7.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run8.mat')
S5_run8 = mat.get('y')
S5_run8 = pd.DataFrame(S5_run8)
S5_run8_transposed = S5_run8.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run9.mat')
S5_run9 = mat.get('y')
S5_run9 = pd.DataFrame(S5_run9)
S5_run9_transposed = S5_run9.transpose()

mat = scipy.io.loadmat('/content/drive/MyDrive/dataset/Fingers_Movement/S5/S5_run10.mat')
S5_run10 = mat.get('y')
S5_run10 = pd.DataFrame(S5_run10)
S5_run10_transposed = S5_run10.transpose()

# %%
S5_run1_transposed
# Out:
#                0              1              2              3    \
# 0         0.000000 -146370.718750 -146349.734375 -145775.562500
# 1         0.001667 -249278.750000 -248978.421875 -248979.093750
# 2         0.003333 -258269.125000 -257999.359375 -258313.640625
# 3         0.005000 -239428.515625 -239225.875000 -239725.234375
# 4         0.006667  -90689.757812  -90480.882812  -91379.789062
# ...            ...            ...            ...            ...
# 134156  223.593333  200333.843750  200489.218750  200035.703125
# 134157  223.595000  271721.187500  271888.750000  272156.531250
# 134158  223.596667  264500.281250  264620.250000  265078.656250
# 134159  223.598333  223180.921875  223292.734375  223769.984375
# 134160  223.600000   31200.103516   31158.400391   31692.806641
#
#                   4              5              6              7    \
# 0      -142544.140625 -145227.234375 -138970.953125 -141068.468750
# ...

# %%
df_S5 = pd.concat([S5_run1_transposed,S5_run2_transposed,S5_run3_transposed,S5_run4_transposed,S5_run5_transposed,S5_run6_transposed,S5_run7_transposed,S5_run8_transposed,S5_run9_transposed,S5_run10_transposed])

# %%
df_S5.shape
# Out:
# (1375198, 258)

# %%
df_S5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1375198 entries, 0 to 138137
# Columns: 258 entries, 0 to 257
# dtypes: float64(258)
# memory usage: 2.7 GB

# %%
df_S5.dropna(inplace=True)

# %%
df_S5.shape
# Out:
# (1375198, 258)

# %%
equilibre_S5 = df_S5[257].value_counts()
print(equilibre_S5)
# Out:
# 0.0    532080
# 5.0    150000
# 2.0    150000
# 6.0    150000
# 3.0    150000
# 4.0    150000
# 7.0     63118
# 1.0     30000
# Name: 257, dtype: int64

# %%
df_S5.shape
# Out:
# (1375198, 258)

# %%
df_S5 = df_S5.drop(0,  axis=1)

# %%
df_S5.shape
# Out:
# (1375198, 257)

# %%
df_S5 = df_S5[df_S5[257] != 0]

# %%
df_S5.shape
# Out:
# (843118, 257)

# %%
df_S5 = df_S5[df_S5[257] != 7]

# %%
df_S5.shape
# Out:
# (780000, 257)

# %%
df_S5.rename(columns = {257:'label'}, inplace = True)
# Out:
# <ipython-input-23-2100c88783b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_S5.rename(columns = {257:'label'}, inplace = True)

# %%
df_S5.columns = df_S5.columns.astype(str)

# %%
df_S5
# Out:
#                     1              2              3              4  \
# 720    -185545.093750 -185547.421875 -185152.609375 -182294.203125
# 721    -255201.500000 -254867.500000 -254933.718750 -254747.234375
# 722    -257901.812500 -257611.718750 -257930.437500 -257942.562500
# 723    -222691.078125 -222450.281250 -222951.609375 -223667.156250
# 724     -34757.960938  -34496.839844  -35335.191406  -38418.765625
# ...               ...            ...            ...            ...
# 131215  206367.015625  206700.531250  207467.000000  206831.343750
# 131216   76570.765625   76670.046875   77417.562500   78794.953125
# 131217 -141329.500000 -141385.765625 -141184.359375 -138495.484375
# 131218 -236660.484375 -236658.828125 -237080.609375 -235714.765625
# 131219 -229892.046875 -230025.578125 -230769.859375 -229947.171875
#
#                     5              6              7              8  \
# 720    -184994.171875 -179314.484375 -181214.937500 -183247.718750
# ...

# %%
df_S5.shape
# Out:
# (780000, 257)

# %%
encoder = LabelEncoder()

df_S5['label'] = encoder.fit_transform(df_S5['label'])
df_S5
# Out:
#                     1              2              3              4  \
# 720    -185545.093750 -185547.421875 -185152.609375 -182294.203125
# 721    -255201.500000 -254867.500000 -254933.718750 -254747.234375
# 722    -257901.812500 -257611.718750 -257930.437500 -257942.562500
# 723    -222691.078125 -222450.281250 -222951.609375 -223667.156250
# 724     -34757.960938  -34496.839844  -35335.191406  -38418.765625
# ...               ...            ...            ...            ...
# 131215  206367.015625  206700.531250  207467.000000  206831.343750
# 131216   76570.765625   76670.046875   77417.562500   78794.953125
# 131217 -141329.500000 -141385.765625 -141184.359375 -138495.484375
# 131218 -236660.484375 -236658.828125 -237080.609375 -235714.765625
# 131219 -229892.046875 -230025.578125 -230769.859375 -229947.171875
#
#                     5              6              7              8  \
# 720    -184994.171875 -179314.484375 -181214.937500 -183247.718750
# ...

# %%
df_S5.reset_index(drop=True)
# Out:
#                     1              2              3              4  \
# 0      -185545.093750 -185547.421875 -185152.609375 -182294.203125
# 1      -255201.500000 -254867.500000 -254933.718750 -254747.234375
# 2      -257901.812500 -257611.718750 -257930.437500 -257942.562500
# 3      -222691.078125 -222450.281250 -222951.609375 -223667.156250
# 4       -34757.960938  -34496.839844  -35335.191406  -38418.765625
# ...               ...            ...            ...            ...
# 779995  206367.015625  206700.531250  207467.000000  206831.343750
# 779996   76570.765625   76670.046875   77417.562500   78794.953125
# 779997 -141329.500000 -141385.765625 -141184.359375 -138495.484375
# 779998 -236660.484375 -236658.828125 -237080.609375 -235714.765625
# 779999 -229892.046875 -230025.578125 -230769.859375 -229947.171875
#
#                     5              6              7              8  \
# 0      -184994.171875 -179314.484375 -181214.937500 -183247.718750
# ...

# %%
y_df = df_S5['label'].values

# %%
print(f"#Samples Rest     {(y_df[y_df==0].shape)[0]} and label is {y_df[y_df==0][0]}")
print(f"#Samples thumb    {(y_df[y_df==1].shape)[0]} and label is {y_df[y_df==1][0]}")
print(f"#Samples index    {(y_df[y_df==2].shape)[0]} and label is {y_df[y_df==2][0]}")
print(f"#Samples middle   {(y_df[y_df==3].shape)[0]} and label is {y_df[y_df==3][0]}")
print(f"#Samples ring     {(y_df[y_df==4].shape)[0]} and label is {y_df[y_df==4][0]}")
print(f"#Samples little   {(y_df[y_df==5].shape)[0]} and label is {y_df[y_df==5][0]}")
# Out:
# #Samples Rest     30000 and label is 0
# #Samples thumb    150000 and label is 1
# #Samples index    150000 and label is 2
# #Samples middle   150000 and label is 3
# #Samples ring     150000 and label is 4
# #Samples little   150000 and label is 5

# %%
equilibre_df_S5= df_S5['label'].value_counts()
equilibre_df_S5
# Out:
# 4    150000
# 1    150000
# 5    150000
# 2    150000
# 3    150000
# 0     30000
# Name: label, dtype: int64

# %%
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(equilibre_df_S5, labels=['middle','little','thumb','ring','index','rest'], colors=['red','green','blue', 'yellow', 'brown','orange'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
Train, Test = train_test_split(df_S5, test_size=0.2, random_state=42, shuffle=True)

# %%
Train.head()
# Out:
#                     1              2              3              4  \
# 100371 -124986.132812 -125089.648438 -124703.109375 -121728.968750
# 32536  -214295.390625 -214445.062500 -214701.406250 -212535.734375
# 114399  259201.187500  259369.750000  260202.859375  258681.000000
# 97535   230449.500000  230609.421875  231040.546875  227747.671875
# 93349    90693.835938   90774.593750   91473.531250   92656.031250
#
#                     5              6              7              8  \
# 100371 -124107.656250 -118113.609375 -120731.281250 -123184.125000
# 32536  -214482.734375 -210139.500000 -212593.703125 -213602.265625
# 114399  259981.125000  257122.218750  257626.140625  258788.359375
# 97535   229773.937500  225131.953125  227297.765625  229158.453125
# 93349    92095.601562   94202.140625   92672.492188   91359.453125
#
#                     9             10  ...            248            249  \
# 100371 -123399.867188 -122752.468750  ... -118838.968750 -124877.421875
# ...

# %%
Train.shape
# Out:
# (624000, 257)

# %%
Test.shape
# Out:
# (156000, 257)

# %%
y_Train = Train.iloc[:,-1]
y_Test = Test.iloc[:,-1]

# %%
print(f"#Samples Rest   in Train {(y_Train[y_Train==0].shape)[0]}, in Test {(y_Test[y_Test==0].shape)[0]}")
print(f"#Samples Thumb  in Train {(y_Train[y_Train==1].shape)[0]}, in Test {(y_Test[y_Test==1].shape)[0]}")
print(f"#Samples Index  in Train {(y_Train[y_Train==2].shape)[0]}, in Test {(y_Test[y_Test==2].shape)[0]}")
print(f"#Samples Middle in Train {(y_Train[y_Train==3].shape)[0]}, in Test {(y_Test[y_Test==3].shape)[0]}")
print(f"#Samples Ring   in Train {(y_Train[y_Train==4].shape)[0]}, in Test {(y_Test[y_Test==4].shape)[0]}")
print(f"#Samples Little in Train {(y_Train[y_Train==5].shape)[0]}, in Test {(y_Test[y_Test==5].shape)[0]}")
# Out:
# #Samples Rest   in Train 23934, in Test 6066
# #Samples Thumb  in Train 120002, in Test 29998
# #Samples Index  in Train 119966, in Test 30034
# #Samples Middle in Train 119933, in Test 30067
# #Samples Ring   in Train 120288, in Test 29712
# #Samples Little in Train 119877, in Test 30123

# %%
Train.to_csv("/content/drive/MyDrive/dataset/Fingers/Fingers_Train_S5.csv",index=False)

# %%
Test.to_csv("/content/drive/MyDrive/dataset/Fingers/Fingers_Test_S5.csv",index=False)
